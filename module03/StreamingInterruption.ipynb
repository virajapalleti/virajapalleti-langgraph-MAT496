# %% [markdown]
# # Streaming
#
# ## Review
#
# In module 2, covered a few ways to customize graph state and memory.
#
# We built up to a Chatbot with external memory that can sustain long-running conversations.
#
# ## Goals
#
# This module will dive into `human-in-the-loop`, which builds on memory and allows users to interact directly with graphs in various ways.
#
# To set the stage for `human-in-the-loop`, we'll first dive into streaming, which provides several ways to visualize graph output (e.g., node state or chat model tokens) over the course of execution.

# %%
# %%capture --no-stderr
# %pip install --quiet -U langgraph langchain_openai langgraph_sdk

# %% [markdown]
# ## Streaming
#
# Let's set up our Chatbot from Module 2

# %%
import os, getpass

def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

_set_env("OPENAI_API_KEY")

# %%
from IPython.display import Image, display

from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage, RemoveMessage
from langchain_core.runnables import RunnableConfig

from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import StateGraph, START, END
from langgraph.graph import MessagesState

# LLM
model = ChatOpenAI(model="gpt-4o", temperature=0) 

# State 
class State(MessagesState):
    summary: str

# Define the logic to call the model
def call_model(state: State, config: RunnableConfig):
    
    # Get summary if it exists
    summary = state.get("summary", "")

    # If there is summary, then we add it
    if summary:
        
        # Add summary to system message
        system_message = f"Summary of conversation earlier: {summary}"

        # Append summary to any newer messages
        messages = [SystemMessage(content=system_message)] + state["messages"]
    
    else:
        messages = state["messages"]
    
    response = model.invoke(messages, config)
    return {"messages": response}

def summarize_conversation(state: State):
    
    # First, we get any existing summary
    summary = state.get("summary", "")

    # Create our summarization prompt 
    if summary:
        
        # A summary already exists
        summary_message = (
            f"This is summary of the conversation to date: {summary}\n\n"
            "Extend the summary by taking into account the new messages above:"
        )
        
    else:
        summary_message = "Create a summary of the conversation above:"

    # Add prompt to our history
    messages = state["messages"] + [HumanMessage(content=summary_message)]
    response = model.invoke(messages)
    
    # Delete all but the 2 most recent messages
    delete_messages = [RemoveMessage(id=m.id) for m in state["messages"][:-2]]
    return {"summary": response.content, "messages": delete_messages}

# Determine whether to end or summarize the conversation
def should_continue(state: State):
    
    """Return the next node to execute."""
    
    messages = state["messages"]
    
    # If there are more than six messages, then we summarize the conversation
    if len(messages) > 6:
        return "summarize_conversation"
    
    # Otherwise we can just end
    return END

# Define a new graph
workflow = StateGraph(State)
workflow.add_node("conversation", call_model)
workflow.add_node(summarize_conversation)

# Set the entrypoint as conversation
workflow.add_edge(START, "conversation")
workflow.add_conditional_edges("conversation", should_continue)
workflow.add_edge("summarize_conversation", END)

# Compile
memory = MemorySaver()
graph = workflow.compile(checkpointer=memory)
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# ### Streaming full state
#
# Now, let's talk about ways to stream our graph state
#
# `.stream` and `.astream` are sync and async methods for streaming back results.
#
# LangGraph supports a few different streaming modes for graph state
#
# * `values`: This streams the full state of the graph after each node is called.
# * `updates`: This streams updates to the state of the graph after each node is called.
#
# ![values_vs_updates.png](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66dbaf892d24625a201744e5_streaming1.png)
#
# Let's look at `stream_mode="updates"`.
#
# Because we stream with `updates`, we only see updates to the state after node in the graph is run.
#
# Each `chunk` is a dict with `node_name` as the key and the updated state as the value.

# %%
# Create a thread
config = {"configurable": {"thread_id": "1"}}

# Start conversation
for chunk in graph.stream({"messages": [HumanMessage(content="hi! I'm Viraja and I'm 19")]}, config, stream_mode="updates"):
    print(chunk)
# Out:
# {'conversation': {'messages': AIMessage(content="Hi Viraja! It's nice to meet you. How can I help you today?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 38, 'total_tokens': 55, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cbf1785567', 'id': 'chatcmpl-CVCV6lVrmEUhUqoVKuPhVuxXLcwl1', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--96a616e8-f3a9-40ed-96bf-29f0b23e5046-0', usage_metadata={'input_tokens': 38, 'output_tokens': 17, 'total_tokens': 55, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})}}

# %% [markdown]
# Let's now just print the state update.

# %%
# Start conversation
for chunk in graph.stream({"messages": [HumanMessage(content="hi! I'm Viraja and I'm 19")]}, config, stream_mode="updates"):
    chunk['conversation']["messages"].pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Hi Viraja! It's great to meet you. How are you doing today?

# %% [markdown]
# Now, we can see `stream_mode="values"`.
#
# This is the `full state` of the graph after the `conversation` node is called.

# %%
# Start conversation, again
config = {"configurable": {"thread_id": "2"}}

# Start conversation
input_message = HumanMessage(content="hi! I'm Viraja")
for event in graph.stream({"messages": [input_message]}, config, stream_mode="values"):
    for m in event['messages']:
        m.pretty_print()
    print("---"*25)
# Out:
# ================================ Human Message =================================
#
# hi! I'm Viraja
# ---------------------------------------------------------------------------
# ================================ Human Message =================================
#
# hi! I'm Viraja
# ================================== Ai Message ==================================
#
# Hello, Viraja! How can I assist you today?
# ---------------------------------------------------------------------------

# %% [markdown]
# ### Streaming tokens
#
# We often want to stream more than graph state.
#
# In particular, with chat model calls it is common to stream the tokens as they are generated.
#
# We can do this [using the `.astream_events` method](https://langchain-ai.github.io/langgraph/how-tos/streaming-from-final-node/#stream-outputs-from-the-final-node), which streams back events as they happen inside nodes!
#
# Each event is a dict with a few keys:
#
# * `event`: This is the type of event that is being emitted.
# * `name`: This is the name of event.
# * `data`: This is the data associated with the event.
# * `metadata`: Contains`langgraph_node`, the node emitting the event.
#
# Let's have a look.

# %%
config = {"configurable": {"thread_id": "3"}}
input_message = HumanMessage(content="Tell me about the famour tennis players")
async for event in graph.astream_events({"messages": [input_message]}, config, version="v2"):
    print(f"Node: {event['metadata'].get('langgraph_node','')}. Type: {event['event']}. Name: {event['name']}")
# Out:
# Node: . Type: on_chain_start. Name: LangGraph
# Node: conversation. Type: on_chain_start. Name: conversation
# Node: conversation. Type: on_chat_model_start. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_stream. Name: ChatOpenAI
# Node: conversation. Type: on_chat_model_end. Name: ChatOpenAI
# Node: conversation. Type: on_chain_start. Name: should_continue
# Node: conversation. Type: on_chain_end. Name: should_continue
# Node: conversation. Type: on_chain_stream. Name: conversation
# Node: conversation. Type: on_chain_end. Name: conversation
# Node: . Type: on_chain_stream. Name: LangGraph
# Node: . Type: on_chain_end. Name: LangGraph

# %% [markdown]
# The central point is that tokens from chat models within your graph have the `on_chat_model_stream` type.
#
# We can use `event['metadata']['langgraph_node']` to select the node to stream from.
#
# And we can use `event['data']` to get the actual data for each event, which in this case is an `AIMessageChunk`.

# %%
node_to_stream = 'conversation'
config = {"configurable": {"thread_id": "4"}}
input_message = HumanMessage(content="Tell me about the famour tennis players")
async for event in graph.astream_events({"messages": [input_message]}, config, version="v2"):
    # Get chat model tokens from a particular node 
    if event["event"] == "on_chat_model_stream" and event['metadata'].get('langgraph_node','') == node_to_stream:
        print(event["data"])
# Out:
# {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='Certainly', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='!', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Here', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' are', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' some', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' most', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' famous', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' tennis', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' players', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' both', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' past', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' present', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' who', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' have', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' made', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' significant', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' impacts', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' on', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' sport', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=':\n\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='###', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Men', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='’s', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Tennis', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Players', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='\n\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='1', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='Roger', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Federer', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=':\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='  ', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' -', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' National', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='ity', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Swiss', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='  ', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' -', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Known', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' for', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' his', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' grace', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' on', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' court', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' exceptional', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' all', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='-around', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' game', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='.\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='  ', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' -', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Has', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' won', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='20', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Grand', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Slam', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' singles', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' titles', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' including', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' record', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' eight', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Wimbledon', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' titles', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='2', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='R', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='afael', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Nadal', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=':\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='  ', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' -', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' National', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='ity', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Spanish', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='  ', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' -', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Known', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' as', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' "', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='King', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Clay', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='"', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' for', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' his', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' dominance', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' on', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' clay', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' courts', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='.\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='  ', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' -', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Has', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' won', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='22', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Grand', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Slam', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' singles', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' titles', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' including', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='14', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' French', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Open', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' titles', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='3', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='Nov', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='ak', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Djokovic', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=':\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='  ', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' -', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' National', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='ity', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Serbian', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='  ', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' -', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Known', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' for', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' his', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' incredible', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' flexibility', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' defensive', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' skills', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' mental', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' toughness', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='.\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='  ', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' -', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Has', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' won', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='24', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Grand', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Slam', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' singles', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' titles', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' holding', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' record', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' for', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' most', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=" men's", additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' tennis', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='4', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='Rod', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' L', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='aver', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=':\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='  ', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' -', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' National', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='ity', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Australian', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='  ', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' -', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' The', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' only', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' player', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' to', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' have', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' won', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Grand', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Slam', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='all', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' four', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' major', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' titles', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' single', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' year', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=')', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' twice', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='196', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='2', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='196', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='9', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='5', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='Pete', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Sam', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='pras', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=':\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='  ', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' -', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' National', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='ity', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' American', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='  ', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' -', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Known', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' for', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' his', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' powerful', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' serve', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' volley', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' game', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='.\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='  ', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' -', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Won', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='14', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Grand', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Slam', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' singles', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' titles', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=',', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' including', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' seven', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Wimbledon', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' titles', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='###', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Women', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='’s', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Tennis', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Players', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='\n\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='1', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='Ser', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='ena', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Williams', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=':\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='  ', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' -', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' National', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='ity', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' American', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='  ', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' -', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Known', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' for', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# ...
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='197', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='0', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='s', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='198', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='0', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='s', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='5', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' **', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='Marg', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='aret', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Court', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='**', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=':\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='  ', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' -', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' National', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='ity', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=':', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Australian', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='  ', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' -', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Holds', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' record', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' for', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' most', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Grand', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Slam', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' singles', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' titles', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' with', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' ', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='24', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='.\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='  ', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' -', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Known', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' for', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' her', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' powerful', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' serve', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' volley', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' game', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='.\n\n', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='These', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' players', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' have', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' not', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' only', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' achieved', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' remarkable', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' success', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' on', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' court', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' but', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' have', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' also', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' contributed', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' to', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' popularity', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' global', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' reach', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' of', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' tennis', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' Each', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' has', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' their', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' own', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' unique', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' style', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' and', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' has', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' left', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' a', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' lasting', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' legacy', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' in', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' the', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content=' sport', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='.', additional_kwargs={}, response_metadata={'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351')}
# {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_a788c5aef0', 'service_tier': 'default', 'model_provider': 'openai'}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351', chunk_position='last')}
# {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351', usage_metadata={'input_tokens': 15, 'output_tokens': 564, 'total_tokens': 579, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})}
# {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--a5845168-db58-47d8-8d9e-2f0ba7e1d351', chunk_position='last')}

# %% [markdown]
# As you see above, just use the `chunk` key to get the `AIMessageChunk`.

# %%
config = {"configurable": {"thread_id": "5"}}
input_message = HumanMessage(content="Tell me about the famour tennis players")
async for event in graph.astream_events({"messages": [input_message]}, config, version="v2"):
    # Get chat model tokens from a particular node 
    if event["event"] == "on_chat_model_stream" and event['metadata'].get('langgraph_node','') == node_to_stream:
        data = event["data"]
        print(data["chunk"].content, end="|")
# Out:
# |Certainly|!| Here| are| some| of| the| most| famous| tennis| players|,| both| past| and| present|,| who| have| made| significant| impacts| on| the| sport|:
#
# |###| Men|
#
# |1|.| **|Roger| Federer|**|:
# |  | -| **|Nationality|**|:| Swiss|
# |  | -| **|Grand| Slam| Titles|**|:| |20|
# |  | -| Known| for| his| grace| on| the| court|,| Federer| is| often| considered| one| of| the| greatest| tennis| players| of| all| time|.| His| rivalry| with| Rafael| Nadal| and| Novak| Djokovic| is| legendary|.
#
# |2|.| **|R|afael| Nadal|**|:
# |  | -| **|Nationality|**|:| Spanish|
# |  | -| **|Grand| Slam| Titles|**|:| |22| (|as| of| |202|3|)
# |  | -| Ren|owned| for| his| dominance| on| clay| courts|,| Nadal| is| often| called| the| "|King| of| Clay|."| His| intense| playing| style| and| ten|acity| have| earned| him| numerous| titles|.
#
# |3|.| **|Nov|ak| Djokovic|**|:
# |  | -| **|Nationality|**|:| Serbian|
# |  | -| **|Grand| Slam| Titles|**|:| |24| (|as| of| |202|3|)
# |  | -| Known| for| his| incredible| flexibility| and| defensive| skills|,| Djokovic| has| been| a| dominant| force| in| men's| tennis|,| holding| numerous| records|.
#
# |4|.| **|Pete| Sam|pras|**|:
# |  | -| **|Nationality|**|:| American|
# |  | -| **|Grand| Slam| Titles|**|:| |14|
# |  | -| A| dominant| player| in| the| |199|0|s|,| Sam|pras| was| known| for| his| powerful| serve| and| volley| game|.
#
# |5|.| **|Bj|örn| Borg|**|:
# |  | -| **|Nationality|**|:| Swedish|
# |  | -| **|Grand| Slam| Titles|**|:| |11|
# |  | -| Borg| was| a| key| figure| in| tennis| during| the| |197|0|s| and| early| |198|0|s|,| known| for| his| calm| demeanor| and| exceptional| baseline| play|.
#
# |###| Women|
#
# |1|.| **|Ser|ena| Williams|**|:
# |  | -| **|Nationality|**|:| American|
# |  | -| **|Grand| Slam| Titles|**|:| |23|
# |  | -| Wid|ely| regarded| as| one| of| the| greatest| female| tennis| players|,| Serena|'s| powerful| game| and| competitive| spirit| have| made| her| a| dominant| force| in| women's| tennis|.
#
# |2|.| **|Ste|ffi| Graf|**|:
# |  | -| **|Nationality|**|:| German|
# |  | -| **|Grand| Slam| Titles|**|:| |22|
# |  | -| Graf| was| known| for| her| versatility| and| powerful| fore|hand|.| She| achieved| a| Golden| Slam| in| |198|8|,| winning| all| four| Grand| Slam| titles| and| the| Olympic| gold| medal| in| the| same| year|.
#
# |3|.| **|Mart|ina| Nav|rat|il|ova|**|:
# |  | -| **|Nationality|**|:| Czech|-American|
# |  | -| **|Grand| Slam| Singles| Titles|**|:| |18|
# |  | -| Nav|rat|il|ova| was| a| dominant| player| in| the| late| |197|0|s| and| |198|0|s|,| known| for| her| exceptional| net| play| and| fitness|.
#
# |4|.| **|Chris| E|vert|**|:
# |  | -| **|Nationality|**|:| American|
# |  | -| **|Grand| Slam| Titles|**|:| |18|
# |  | -| E|vert| was| known| for| her| consistency| and| baseline| game|,| dominating| women's| tennis| in| the| |197|0|s| and| |198|0|s|.
#
# |5|.| **|Marg|aret| Court|**|:
# |  | -| **|Nationality|**|:| Australian|
# |  | -| **|Grand| Slam| Titles|**|:| |24|
# |  | -| Court| holds| the| record| for| the| most| Grand| Slam| singles| titles| in| history| and| was| a| dominant| player| in| the| |196|0|s| and| early| |197|0|s|.
#
# |These| players| have| not| only| achieved| remarkable| success| on| the| court| but| have| also| contributed| to| the| popularity| and| global| reach| of| tennis|.||||

# %%
from langchain_core.messages import convert_to_messages
thread = await client.threads.create()
input_message = HumanMessage(content="Multiply 2 and 3")
async for event in client.runs.stream(thread["thread_id"], assistant_id="agent", input={"messages": [input_message]}, stream_mode="values"):
    messages = event.data.get('messages',None)
    if messages:
        print(convert_to_messages(messages)[-1])
    print('='*25)
# Out:
# =========================
# content='Multiply 2 and 3' additional_kwargs={'additional_kwargs': {'example': False, 'additional_kwargs': {}, 'response_metadata': {}}, 'response_metadata': {}, 'example': False} id='f51807de-6b99-4da4-a798-26cf59d16412'
# =========================
# content='' additional_kwargs={'additional_kwargs': {'tool_calls': [{'index': 0, 'id': 'call_imZHAw7kvMR2ZeKaQVSlj25C', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}]}, 'response_metadata': {'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5'}, 'example': False, 'invalid_tool_calls': [], 'usage_metadata': None} id='run-fa4ab1c6-274d-4be5-8c4a-a6411c7c35cc' tool_calls=[{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_imZHAw7kvMR2ZeKaQVSlj25C', 'type': 'tool_call'}]
# =========================
# content='6' additional_kwargs={'additional_kwargs': {}, 'response_metadata': {}, 'status': 'success'} name='multiply' id='3e7bbfb6-aa82-453a-969c-9c753fbd1d74' tool_call_id='call_imZHAw7kvMR2ZeKaQVSlj25C'
# =========================
# content='The result of multiplying 2 and 3 is 6.' additional_kwargs={'additional_kwargs': {}, 'response_metadata': {'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-05-13', 'system_fingerprint': 'fp_157b3831f5'}, 'example': False, 'invalid_tool_calls': [], 'usage_metadata': None} id='run-e8e0d672-cfb2-42be-850a-345df3718f69'
# =========================

# %% [markdown]
# There are some new streaming mode that are only supported via the API.
#
# For example, we can [use `messages` mode](https://langchain-ai.github.io/langgraph/cloud/how-tos/stream_messages/) to better handle the above case!
#
# This mode currently assumes that you have a `messages` key in your graph, which is a list of messages.
#
# All events emitted using `messages` mode have two attributes:
#
# * `event`: This is the name of the event
# * `data`: This is data associated with the event

# %%
thread = await client.threads.create()
input_message = HumanMessage(content="Multiply 2 and 3")
async for event in client.runs.stream(thread["thread_id"], 
                                      assistant_id="agent", 
                                      input={"messages": [input_message]}, 
                                      stream_mode="messages"):
    print(event.event)
# Out:
# metadata
# messages/complete
# messages/metadata
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/complete
# messages/complete
# messages/metadata
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/partial
# messages/complete

# %% [markdown]
# We can see a few events:
#
# * `metadata`: metadata about the run
# * `messages/complete`: fully formed message
# * `messages/partial`: chat model tokens
#
# You can dig further into the types [here](https://langchain-ai.github.io/langgraph/cloud/concepts/api/#modemessages).
#
# Now, let's show how to stream these messages.
#
# We'll define a helper function for better formatting of the tool calls in messages.
